# %% [markdown]
# **REGRESSION**

# %% [markdown]
# 1. What is Simple Linear Regression?
#
# Answer: Simple Linear Regression is a technique that models the relationship between one independent variable (X) and one dependent variable (Y) using a straight line:
# 𝑌
# =
# 𝑚
# 𝑋
# +
# 𝑐
# Y=mX+c.
#
# 2. What are the key assumptions of Simple Linear Regression?
#
# Answer:
#
# Linearity between X and Y
#
# Independence of residuals
#
# Homoscedasticity (equal error variance)
#
# Normal distribution of residuals
#
# 3. What does the coefficient m represent in the equation
# 𝑌
# =
# 𝑚
# 𝑋
# +
# 𝑐
# Y=mX+c?
#
# Answer: It represents the slope — the change in Y for every one-unit increase in X.
#
# 4. What does the intercept c represent in the equation
# 𝑌
# =
# 𝑚
# 𝑋
# +
# 𝑐
# Y=mX+c?
#
# Answer: It is the predicted value of Y when X = 0 — the point where the line crosses the Y-axis.
#
# 5. How do we calculate the slope m in Simple Linear Regression?
#
# Answer:
#
# 𝑚
# =
# 𝑛
# ∑
# 𝑋
# 𝑌
# −
# ∑
# 𝑋
# ∑
# 𝑌
# 𝑛
# ∑
# 𝑋
# 2
# −
# (
# ∑
# 𝑋
# )
# 2
# m=
# n∑X
# 2
#  −(∑X)
# 2
#
# n∑XY−∑X∑Y
# ​
#
# 6. What is the purpose of the least squares method in Simple Linear Regression?
#
# Answer: To minimize the sum of squared differences between the actual Y values and predicted Y values.
#
# 7. How is the coefficient of determination (R²) interpreted in Simple Linear Regression?
#
# Answer: R² indicates the percentage of variance in Y explained by X. For example, R² = 0.85 means 85% of Y is explained by X.
#
# 8. What is Multiple Linear Regression?
#
# Answer: A regression model that uses two or more independent variables to predict the dependent variable Y.
#
# 9. What is the main difference between Simple and Multiple Linear Regression?
#
# Answer: Simple uses one independent variable; Multiple uses two or more independent variables.
#
# 10. What are the key assumptions of Multiple Linear Regression?
#
# Answer:
#
# Linearity
#
# Independence of errors
#
# Homoscedasticity
#
# No multicollinearity
#
# Normal distribution of residuals
#
# 11. What is heteroscedasticity, and how does it affect the results of a Multiple Linear Regression model?
#
# Answer: Heteroscedasticity means unequal variance of errors. It can lead to biased standard errors, affecting hypothesis testing and confidence intervals.
#
# 12. How can you improve a Multiple Linear Regression model with high multicollinearity?
#
# Answer:
#
# Remove or combine correlated variables
#
# Use dimensionality reduction (PCA)
#
# Apply regularization methods like Ridge or Lasso regression
#
# 13. What are some common techniques for transforming categorical variables for use in regression models?
#
# Answer:
#
# One-Hot Encoding
#
# Label Encoding
#
# Ordinal Encoding
#
# 14. What is the role of interaction terms in Multiple Linear Regression?
#
# Answer: Interaction terms allow the effect of one variable to depend on another, improving model accuracy when relationships aren’t purely additive.
#
# 15. How can the interpretation of intercept differ between Simple and Multiple Linear Regression?
#
# Answer: In multiple regression, the intercept is the value of Y when all Xs = 0, which might not always be meaningful or practical.
#
# 16. What is the significance of the slope in regression analysis, and how does it affect predictions?
#
# Answer: The slope indicates how much the dependent variable changes with a unit change in an independent variable — crucial for understanding impact.
#
# 17. How does the intercept in a regression model provide context for the relationship between variables?
#
# Answer: It sets the baseline value of Y when all independent variables are zero, helping frame the starting point of predictions.
#
# 18. What are the limitations of using R² as a sole measure of model performance?
#
# Answer:
#
# Doesn’t indicate if the model is correct
#
# Can increase with more variables (even irrelevant ones)
#
# Doesn’t detect overfitting
#
# 19. How would you interpret a large standard error for a regression coefficient?
#
# Answer: It suggests high uncertainty around the coefficient estimate — the predictor may not be statistically significant.
#
# 20. How can heteroscedasticity be identified in residual plots, and why is it important to address it?
#
# Answer: If residuals fan out or form patterns in plots, heteroscedasticity may be present. It weakens the reliability of inference and confidence intervals.
#
# 21. What does it mean if a Multiple Linear Regression model has a high R² but low adjusted R²?
#
# Answer: It means some predictors don't improve the model, and R² is artificially inflated. Adjusted R² penalizes unnecessary variables.
#
# 22. Why is it important to scale variables in Multiple Linear Regression?
#
# Answer: To ensure fair comparison and interpretation, especially when variables have different units or when using regularization techniques.
#
# 23. What is polynomial regression?
#
# Answer: A regression technique where the relationship between X and Y is modeled as an nth-degree polynomial:
#
# 𝑌
# =
# 𝑏
# 0
# +
# 𝑏
# 1
# 𝑋
# +
# 𝑏
# 2
# 𝑋
# 2
# +
# .
# .
# .
# +
# 𝑏
# 𝑛
# 𝑋
# 𝑛
# Y=b
# 0
# ​
#  +b
# 1
# ​
#  X+b
# 2
# ​
#  X
# 2
#  +...+b
# n
# ​
#  X
# n
#
# 24. How does polynomial regression differ from linear regression?
#
# Answer: Linear regression fits a straight line; polynomial regression fits a curve to capture non-linear relationships.
#
# 25. When is polynomial regression used?
#
# Answer: When the data shows a non-linear pattern and a straight line doesn't fit well.
#
# 26. What is the general equation for polynomial regression?
#
# Answer:
#
# 𝑌
# =
# 𝑏
# 0
# +
# 𝑏
# 1
# 𝑋
# +
# 𝑏
# 2
# 𝑋
# 2
# +
# ⋯
# +
# 𝑏
# 𝑛
# 𝑋
# 𝑛
# Y=b
# 0
# ​
#  +b
# 1
# ​
#  X+b
# 2
# ​
#  X
# 2
#  +⋯+b
# n
# ​
#  X
# n
#
# 27. Can polynomial regression be applied to multiple variables?
#
# Answer: Yes, it’s called multivariate polynomial regression, where polynomial terms are used for multiple features.
#
# 28. What are the limitations of polynomial regression?
#
# Answer:
#
# Overfitting with high degrees
#
# Hard to interpret
#
# Sensitive to outliers
#
# 29. What methods can be used to evaluate model fit when selecting the degree of a polynomial?
#
# Answer:
#
# Cross-validation
#
# Adjusted R²
#
# Root Mean Squared Error (RMSE)
#
# Plotting and visual inspection
#
# 30. Why is visualization important in polynomial regression?
#
# Answer: It helps determine if the polynomial curve is a good fit or if it’s over/underfitting the data.
#
# 31. How is polynomial regression implemented in Python?
#
# Answer:
#
# python
# Copy
# Edit
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(PolynomialFeatures(2), LinearRegression())
# model.fit(X_train, y_train)
